# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Get the path of the current script (test_script.py)
current_dir = Path.cwd()
data_path = current_dir / 'data' / 'AB_NYC_2019.csv'

# Print the absolute path for verification (optional)
print(f"Image path: {data_path.absolute()}")
# Out:
# Image path: C:\Users\endie\Documents\codes\python\practice\data-fundamentals\data\AB_NYC_2019.csv

# %%
pd_data = pd.read_csv(data_path, index_col='id')
print(f"The data shape: {pd_data.shape}")
pd_data.head()
# Out:
# The data shape: (48895, 15)
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
prices = pd_data['price']
type(prices)
# Out:
# pandas.core.series.Series

# %%
pd_data[pd_data['price'] == 10000]
# Out:
#                                                      name   host_id host_name  \
# id
# 7003697               Furnished room in Astoria apartment  20582832  Kathrine
# 13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901      Erin
# 22436899                              1-BR Lincoln Center  72390391    Jelena
#
#          neighbourhood_group    neighbourhood  latitude  longitude  \
# id
# 7003697               Queens          Astoria  40.76810  -73.91651
# 13894339            Brooklyn       Greenpoint  40.73260  -73.95739
# 22436899           Manhattan  Upper West Side  40.77213  -73.98665
#
#                 room_type  price  minimum_nights  number_of_reviews  \
# id
# 7003697      Private room  10000             100                  2
# 13894339  Entire home/apt  10000               5                  5
# 22436899  Entire home/apt  10000              30                  0
#
#          last_review  reviews_per_month  calculated_host_listings_count  \
# id
# ...

# %%
prices.min()
# Out:
# 0

# %%
prices.max()
# Out:
# 10000

# %%
plt.hist(prices,bins=30, range=(prices.min(), prices.max()))
# Set y-axis to log scale
plt.yscale('log')
plt.show()

# %%
pd_data_brooklyn_price_2000_plus = pd_data[(pd_data['price'] >= 2000) & (pd_data['neighbourhood_group'] == "Brooklyn")]

print(f"The data shape is: {pd_data_brooklyn_price_2000_plus.shape}")
pd_data_brooklyn_price_2000_plus.head()
# Out:
# The data shape is: (25, 15)
#                                      name   host_id host_name  \
# id
# 826690   Sunny, Family-Friendly 2 Bedroom   4289240      Lucy
# 2271504  SUPER BOWL Brooklyn Duplex Apt!!  11598359  Jonathan
# 2919330  NearWilliamsburg bridge 11211 BK  14908606    Bianca
# 2952861              Photography Location   1177497   Jessica
# 2953058                     Film Location   1177497   Jessica
#
#         neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# 826690             Brooklyn    Prospect Heights  40.67919  -73.97191
# 2271504            Brooklyn        Clinton Hill  40.68766  -73.96439
# 2919330            Brooklyn  Bedford-Stuyvesant  40.69572  -73.95731
# 2952861            Brooklyn        Clinton Hill  40.69127  -73.96563
# 2953058            Brooklyn        Clinton Hill  40.69137  -73.96723
#
#                room_type  price  minimum_nights  number_of_reviews  \
# id
# ...
